# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
import time
import math
import theano
import theano.tensor as T
import lasagne
import numpy as np
import matplotlib.pyplot as plt
import scipy.ndimage as ndimage
import scipy.ndimage.filters as filters

from skimage import measure
from data import generate as generate_training_data
from network import setup as setup_network

def sample_box(img, x, y):
        box = np.zeros((1,1,box_size,box_size))
        margin = int(math.floor(box_size / 2))
        box[0:,0:,:]=img[x-margin:x+margin+1, y-margin:y+margin+1]
        return box

# %% [markdown]
# ## Some hyperparameters

# %%
box_size = 29
num_epochs = 15
learning_rate = 0.00004
sample_radius = 2

# %% [markdown]
# ## Generate training data and visualize

# %%
t_samples, t_labels, t_img = generate_training_data("train",
                                                box_size = box_size,
                                                sample_radius = sample_radius,
                                                enable_plotting = True)

# %% [markdown]
# ## Generate validation data

# %%
v_samples, v_labels, v_img = generate_training_data("validation",
                                                box_size = box_size,
                                                sample_radius = sample_radius)

# %% [markdown]
# ## Normalize data

# %%
mu = t_img.mean()
sigma = t_img.std()

def normalize(data):
    return (data - mu)/sigma

t_img = normalize(t_img)
v_img = normalize(v_img)

# %% [markdown]
# ## Setup network

# %%
input_var = T.tensor4('inputs')
target_var = T.ivector('targets')
network = setup_network(input_var, box_size)

# %% [markdown]
# ## Setup objective function

# %%
# Training
prediction = lasagne.layers.get_output(network)
loss = lasagne.objectives.categorical_crossentropy(prediction, target_var).mean()
train_acc = T.mean(T.eq(T.argmax(prediction, axis=1), target_var), dtype=theano.config.floatX)
params = lasagne.layers.get_all_params(network, trainable=True)
updates = lasagne.updates.nesterov_momentum(loss, params, learning_rate=learning_rate, momentum=0.9)
train_fn = theano.function([input_var, target_var], [loss, train_acc], updates=updates, allow_input_downcast=True)

# Validation
val_prediction = lasagne.layers.get_output(network, deterministic=True)
val_loss = lasagne.objectives.categorical_crossentropy(val_prediction, target_var).mean()
val_acc = T.mean(T.eq(T.argmax(val_prediction, axis=1), target_var), dtype=theano.config.floatX)
val_fn = theano.function([input_var, target_var], [val_loss, val_acc], allow_input_downcast=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-0cba494e9458> in <module>()
#       5 params = lasagne.layers.get_all_params(network, trainable=True)
#       6 updates = lasagne.updates.nesterov_momentum(loss, params, learning_rate=learning_rate, momentum=0.9)
# ----> 7 train_fn = theano.function([input_var, target_var], [loss, train_acc], updates=updates, allow_input_downcast=True)
#       8
#       9 # Validation
#
# /Users/xiayuxuan/anaconda/lib/python2.7/site-packages/theano/compile/function.pyc in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     314                    on_unused_input=on_unused_input,
#     315                    profile=profile,
# --> 316                    output_keys=output_keys)
#     317     # We need to add the flag check_aliased inputs if we have any mutable or
#     318     # borrowed used defined inputs
#
# /Users/xiayuxuan/anaconda/lib/python2.7/site-packages/theano/compile/pfunc.pyc in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys)
#     521                          accept_inplace=accept_inplace, name=name,
#     522                          profile=profile, on_unused_input=on_unused_input,
# --> 523                          output_keys=output_keys)
#     524
#     525
#
# /Users/xiayuxuan/anaconda/lib/python2.7/site-packages/theano/compile/function_module.pyc in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys)
#    1524                    on_unused_input=on_unused_input,
#    1525                    output_keys=output_keys).create(
# -> 1526             defaults)
#    1527
#    1528     t2 = time.time()
#
# /Users/xiayuxuan/anaconda/lib/python2.7/site-packages/theano/compile/function_module.pyc in create(self, input_storage, trustme)
#    1388             theano.config.traceback.limit = 0
#    1389             _fn, _i, _o = self.linker.make_thunk(
# -> 1390                 input_storage=input_storage_lists)
#    1391         finally:
#    1392             theano.config.traceback.limit = limit_orig
#
# /Users/xiayuxuan/anaconda/lib/python2.7/site-packages/theano/gof/link.pyc in make_thunk(self, input_storage, output_storage)
#     605     def make_thunk(self, input_storage=None, output_storage=None):
#     606         return self.make_all(input_storage=input_storage,
# --> 607                              output_storage=output_storage)[:3]
#     608
#     609     def make_all(self, input_storage, output_storage):
#
# /Users/xiayuxuan/anaconda/lib/python2.7/site-packages/theano/gof/vm.pyc in make_all(self, profiler, input_storage, output_storage)
#    1023                                                  storage_map,
#    1024                                                  compute_map,
# -> 1025                                                  no_recycling))
#    1026                 if not hasattr(thunks[-1], 'lazy'):
#    1027                     # We don't want all ops maker to think about lazy Ops.
#
# /Users/xiayuxuan/anaconda/lib/python2.7/site-packages/theano/gof/op.pyc in make_thunk(self, node, storage_map, compute_map, no_recycling)
#     805             try:
#     806                 return self.make_c_thunk(node, storage_map, compute_map,
# --> 807                                          no_recycling)
#     808             except (NotImplementedError, utils.MethodNotDefined):
#     809                 logger.debug('Falling back on perform')
#
# /Users/xiayuxuan/anaconda/lib/python2.7/site-packages/theano/gof/op.pyc in make_c_thunk(self, node, storage_map, compute_map, no_recycling)
#     731         logger.debug('Trying CLinker.make_thunk')
#     732         outputs = cl.make_thunk(input_storage=node_input_storage,
# --> 733                                 output_storage=node_output_storage)
#     734         fill_storage, node_input_filters, node_output_filters = outputs
#     735
#
# /Users/xiayuxuan/anaconda/lib/python2.7/site-packages/theano/gof/cc.pyc in make_thunk(self, input_storage, output_storage, keep_lock)
#    1063         cthunk, in_storage, out_storage, error_storage = self.__compile__(
#    1064             input_storage, output_storage,
# -> 1065             keep_lock=keep_lock)
#    1066
#    1067         res = _CThunk(cthunk, init_tasks, tasks, error_storage)
#
# /Users/xiayuxuan/anaconda/lib/python2.7/site-packages/theano/gof/cc.pyc in __compile__(self, input_storage, output_storage, keep_lock)
#    1005                                     input_storage,
#    1006                                     output_storage,
# -> 1007                                     keep_lock=keep_lock)
#    1008         return (thunk,
#    1009                 [link.Container(input, storage) for input, storage in
#
# /Users/xiayuxuan/anaconda/lib/python2.7/site-packages/theano/gof/cc.pyc in cthunk_factory(self, error_storage, in_storage, out_storage, keep_lock)
#    1433         else:
#    1434             module = get_module_cache().module_from_key(
# -> 1435                 key=key, lnk=self, keep_lock=keep_lock)
#    1436
#    1437         vars = self.inputs + self.outputs + self.orphans
#
# /Users/xiayuxuan/anaconda/lib/python2.7/site-packages/theano/gof/cmodule.pyc in module_from_key(self, key, lnk, keep_lock)
#    1092             try:
#    1093                 location = dlimport_workdir(self.dirname)
# -> 1094                 module = lnk.compile_cmodule(location)
#    1095                 name = module.__file__
#    1096                 assert name.startswith(location)
#
# /Users/xiayuxuan/anaconda/lib/python2.7/site-packages/theano/gof/cc.pyc in compile_cmodule(self, location)
#    1345                 lib_dirs=self.lib_dirs(),
#    1346                 libs=libs,
# -> 1347                 preargs=preargs)
#    1348         except Exception as e:
#    1349             e.args += (str(self.fgraph),)
#
# /Users/xiayuxuan/anaconda/lib/python2.7/site-packages/theano/gof/cmodule.pyc in compile_str(module_name, src_code, location, include_dirs, lib_dirs, libs, preargs, py_module, hide_symbols)
#    2066             open(os.path.join(location, "__init__.py"), 'w').close()
#    2067             assert os.path.isfile(lib_filename)
# -> 2068             return dlimport(lib_filename)
#    2069
#    2070
#
# /Users/xiayuxuan/anaconda/lib/python2.7/site-packages/theano/gof/cmodule.pyc in dlimport(fullpath, suffix)
#     295                 importlib.invalidate_caches()
#     296         t0 = time.time()
# --> 297         rval = __import__(module_name, {}, {}, [module_name])
#     298         t1 = time.time()
#     299         import_time += t1 - t0
#
# ImportError: ('The following error happened while compiling the node', Dot22(Flatten{2}.0, W), '\n', 'dlopen(/Users/xiayuxuan/.theano/compiledir_Darwin-15.3.0-x86_64-i386-64bit-i386-2.7.11-64/tmpqXI_oh/15357f4a51bff61fa945bea566107bed.so, 2): Library not loaded: libmkl_intel_lp64.dylib\n  Referenced from: /Users/xiayuxuan/.theano/compiledir_Darwin-15.3.0-x86_64-i386-64bit-i386-2.7.11-64/tmpqXI_oh/15357f4a51bff61fa945bea566107bed.so\n  Reason: image not found', '[Dot22(<TensorType(float64, matrix)>, W)]')

# %% [markdown]
# ## Optimize parameters

# %%
for epoch in xrange(num_epochs):
    train_err = 0
    train_acc = 0
    val_err = 0
    val_acc = 0
    start_time = time.time()
    
    indices = np.arange(len(t_labels))
    np.random.shuffle(indices)

    for idx in range(0, len(t_labels)):
        ind = indices[idx]
        labels = np.zeros(1)
        labels[0] = t_labels[ind]
        err, acc = train_fn(sample_box(t_img, t_samples[ind][0], t_samples[ind][1]), labels)
        train_err += err
        train_acc += acc

    for idx in range(0, len(v_labels)):
        labels = np.zeros(1)
        labels[0] = v_labels[idx]
        err, acc = val_fn(sample_box(v_img, v_samples[idx][0], v_samples[idx][1]), labels)
        val_err += err
        val_acc += acc

    print("Epoch {} of {} took {:.3f}s".format(epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss:\t{:.6f}".format(train_err / len(t_labels)))
    print("  Training accuracy:\t{:.2f} %".format(train_acc / len(t_labels) * 100))
    print("  validation loss:\t{:.6f}".format(val_err / len(v_labels)))
    print("  validation accuracy:\t{:.2f} %".format(val_acc / len(v_labels) * 100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-ac854aa8ceb7> in <module>()
#      13         labels = np.zeros(1)
#      14         labels[0] = t_labels[ind]
# ---> 15         err, acc = train_fn(sample_box(t_img, t_samples[ind][0], t_samples[ind][1]), labels)
#      16         train_err += err
#      17         train_acc += acc
#
# NameError: name 'train_fn' is not defined

# %% [markdown]
# ## Sliding window

# %%
eval_fn = theano.function([input_var], val_prediction)
output = np.zeros((v_img.shape[0], v_img.shape[1], 2))

# Run the classifier on each patch in the validation image.

margin = int(math.floor(box_size / 2))
for x in xrange(margin, int(v_img.shape[0] - margin)):
    for y in xrange(margin, int(v_img.shape[1]-margin)):
        patch = v_img[x-margin:x+margin+1, y-margin:y+margin+1]
        patch = patch.reshape(1,1, box_size, box_size)
        output[x,y,:] = eval_fn(patch)

# %% [markdown]
# ## Detect local maxima

# %%
# Smooth the response map
heatmap = filters.gaussian_filter(output[:,:,1], 1) 
# Thresholding
seg = heatmap>0.5
# Non-maximum suppression
detections = np.where(np.multiply(seg, heatmap == filters.maximum_filter(heatmap, 3)))

# %% [markdown]
# ## Plot detections

# %%
fig, ax = plt.subplots()
ax.imshow(v_img, interpolation='nearest', cmap=plt.cm.gray)
plt.plot(detections[1], detections[0], 'b.', markersize=12, mew=3)
        
ax.axis('image')
ax.set_xticks([])
ax.set_yticks([])
plt.show()
plt.rcParams['figure.figsize'] = 20,20
