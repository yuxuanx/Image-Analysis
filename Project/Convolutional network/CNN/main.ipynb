# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
import time
import math
import theano
import theano.tensor as T
import lasagne
import numpy as np
import matplotlib.pyplot as plt
import scipy.ndimage as ndimage
import scipy.ndimage.filters as filters

from skimage import measure
from data import generate as generate_training_data
from network import setup as setup_network

def sample_box(img, x, y):
        box = np.zeros((1,1,box_size,box_size))
        margin = int(math.floor(box_size / 2))
        box[0:,0:,:]=img[x-margin:x+margin+1, y-margin:y+margin+1]
        return box
# Out:
# /Users/xiayuxuan/anaconda/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %% [markdown]
# ## Some hyperparameters

# %%
box_size = 29
num_epochs = 40
learning_rate = 0.00004
sample_radius = 2

# %% [markdown]
# ## Generate training data and visualize

# %%
t_samples, t_labels, t_img = generate_training_data("train",
                                                box_size = box_size,
                                                sample_radius = sample_radius,
                                                enable_plotting = True)

# %% [markdown]
# Generate validation data

# %%
v_samples, v_labels, v_img = generate_training_data("validation",
                                                box_size = box_size,
                                                sample_radius = sample_radius)

# %%
test_samples, test_labels, test_img = generate_training_data("test",
                                                box_size = box_size,
                                                sample_radius = sample_radius)

# %% [markdown]
# Setup objective function

# %%
mu = t_img.mean()
sigma = t_img.std()

def normalize(data):
    return (data - mu)/sigma

t_img = normalize(t_img)
v_img = normalize(v_img)
test_img = normalize(test_img)

# %% [markdown]
# ## Setup network

# %%
input_var = T.tensor4('inputs')
target_var = T.ivector('targets')
network = setup_network(input_var, box_size)

# %% [markdown]
# ## Setup objective function

# %%
# Training
prediction = lasagne.layers.get_output(network)
loss = lasagne.objectives.categorical_crossentropy(prediction, target_var).mean()
train_acc = T.mean(T.eq(T.argmax(prediction, axis=1), target_var), dtype=theano.config.floatX)
params = lasagne.layers.get_all_params(network, trainable=True)
updates = lasagne.updates.nesterov_momentum(loss, params, learning_rate=learning_rate, momentum=0.9)
train_fn = theano.function([input_var, target_var], [loss, train_acc], updates=updates, allow_input_downcast=True)

# Validation
val_prediction = lasagne.layers.get_output(network, deterministic=True)
val_loss = lasagne.objectives.categorical_crossentropy(val_prediction, target_var).mean()
val_acc = T.mean(T.eq(T.argmax(val_prediction, axis=1), target_var), dtype=theano.config.floatX)
val_fn = theano.function([input_var, target_var], [val_loss, val_acc], allow_input_downcast=True)
# Out:
# /Users/xiayuxuan/anaconda/lib/python2.7/site-packages/lasagne/layers/conv.py:489: UserWarning: The `image_shape` keyword argument to `tensor.nnet.conv2d` is deprecated, it has been renamed to `input_shape`.
#   border_mode=border_mode)

# %% [markdown]
# ## Optimize parameters

# %%
for epoch in xrange(num_epochs):
    train_err = 0
    train_acc = 0
    val_err = 0
    val_acc = 0
    start_time = time.time()
    
    indices = np.arange(len(t_labels))
    np.random.shuffle(indices)

    for idx in range(0, len(t_labels)):
        ind = indices[idx]
        labels = np.zeros(1)
        labels[0] = t_labels[ind]
        err, acc = train_fn(sample_box(t_img, t_samples[ind][0], t_samples[ind][1]), labels)
        train_err += err
        train_acc += acc

    for idx in range(0, len(v_labels)):
        labels = np.zeros(1)
        labels[0] = v_labels[idx]
        err, acc = val_fn(sample_box(v_img, v_samples[idx][0], v_samples[idx][1]), labels)
        val_err += err
        val_acc += acc

    print("Epoch {} of {} took {:.3f}s".format(epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss:\t{:.6f}".format(train_err / len(t_labels)))
    print("  Training accuracy:\t{:.2f} %".format(train_acc / len(t_labels) * 100))
    print("  validation loss:\t{:.6f}".format(val_err / len(v_labels)))
    print("  validation accuracy:\t{:.2f} %".format(val_acc / len(v_labels) * 100))
# After training, we compute and print the test error:
test_err = 0
test_acc = 0
for idx in range(0, len(test_labels)):
    labels = np.zeros(1)
    labels[0] = test_labels[idx]
    err, acc = val_fn(sample_box(test_img, test_samples[idx][0], test_samples[idx][1]), labels)
    test_err += err
    test_acc += acc
print("Final results:")
print("  testing loss:\t{:.6f}".format(test_err / len(test_labels)))
print("  testing accuracy:\t{:.2f} %".format(test_acc / len(test_labels) * 100))
# Out:
# Epoch 1 of 40 took 1.366s
#   training loss:	0.656809
#   Training accuracy:	67.38 %
#   validation loss:	0.646954
#   validation accuracy:	61.83 %
# Epoch 2 of 40 took 1.271s
#   training loss:	0.622641
#   Training accuracy:	68.72 %
#   validation loss:	0.628580
#   validation accuracy:	61.83 %
# Epoch 3 of 40 took 1.325s
#   training loss:	0.593846
#   Training accuracy:	68.93 %
#   validation loss:	0.609592
#   validation accuracy:	61.83 %
# Epoch 4 of 40 took 1.488s
#   training loss:	0.583563
#   Training accuracy:	69.01 %
#   validation loss:	0.592334
#   validation accuracy:	61.83 %
# Epoch 5 of 40 took 1.630s
#   training loss:	0.564761
#   Training accuracy:	68.84 %
#   validation loss:	0.573249
#   validation accuracy:	61.83 %
# Epoch 6 of 40 took 1.523s
#   training loss:	0.555333
#   Training accuracy:	68.97 %
#   validation loss:	0.552447
#   validation accuracy:	61.83 %
# Epoch 7 of 40 took 1.570s
#   training loss:	0.541985
#   Training accuracy:	68.97 %
#   validation loss:	0.538943
#   validation accuracy:	61.83 %
# Epoch 8 of 40 took 1.523s
#   training loss:	0.528345
#   Training accuracy:	69.05 %
#   validation loss:	0.529702
#   validation accuracy:	61.83 %
# Epoch 9 of 40 took 1.571s
#   training loss:	0.521894
#   Training accuracy:	69.43 %
#   validation loss:	0.513987
#   validation accuracy:	61.83 %
# Epoch 10 of 40 took 1.489s
#   training loss:	0.515074
#   Training accuracy:	70.39 %
#   validation loss:	0.493434
#   validation accuracy:	61.96 %
# Epoch 11 of 40 took 1.532s
#   training loss:	0.506174
#   Training accuracy:	71.10 %
#   validation loss:	0.479241
#   validation accuracy:	65.33 %
# Epoch 12 of 40 took 1.644s
#   training loss:	0.484407
#   Training accuracy:	72.94 %
#   validation loss:	0.437277
#   validation accuracy:	75.24 %
# Epoch 13 of 40 took 1.614s
#   training loss:	0.463931
#   Training accuracy:	74.65 %
#   validation loss:	0.396155
#   validation accuracy:	81.01 %
# Epoch 14 of 40 took 1.593s
#   training loss:	0.419480
#   Training accuracy:	76.54 %
#   validation loss:	0.356753
#   validation accuracy:	85.06 %
# Epoch 15 of 40 took 1.586s
#   training loss:	0.402439
#   Training accuracy:	76.96 %
#   validation loss:	0.368580
#   validation accuracy:	85.02 %
# Epoch 16 of 40 took 1.671s
#   training loss:	0.402797
#   Training accuracy:	78.13 %
#   validation loss:	0.341930
#   validation accuracy:	84.65 %
# Epoch 17 of 40 took 1.565s
#   training loss:	0.370526
#   Training accuracy:	80.22 %
#   validation loss:	0.311183
#   validation accuracy:	89.12 %
# Epoch 18 of 40 took 1.531s
#   training loss:	0.366791
#   Training accuracy:	79.42 %
#   validation loss:	0.297032
#   validation accuracy:	89.58 %
# Epoch 19 of 40 took 1.640s
#   training loss:	0.362834
#   Training accuracy:	80.30 %
#   validation loss:	0.272852
#   validation accuracy:	89.03 %
# Epoch 20 of 40 took 1.595s
#   training loss:	0.351609
#   Training accuracy:	79.88 %
#   validation loss:	0.262975
#   validation accuracy:	90.04 %
# Epoch 21 of 40 took 1.505s
#   training loss:	0.343801
#   Training accuracy:	80.51 %
#   validation loss:	0.251357
#   validation accuracy:	90.04 %
# Epoch 22 of 40 took 1.543s
#   training loss:	0.348158
#   Training accuracy:	80.84 %
#   validation loss:	0.252349
#   validation accuracy:	90.73 %
# Epoch 23 of 40 took 1.593s
#   training loss:	0.329850
#   Training accuracy:	80.97 %
#   validation loss:	0.264418
#   validation accuracy:	87.87 %
# Epoch 24 of 40 took 1.589s
#   training loss:	0.335889
#   Training accuracy:	81.39 %
#   validation loss:	0.278594
#   validation accuracy:	85.52 %
# Epoch 25 of 40 took 1.559s
#   training loss:	0.340693
#   Training accuracy:	81.14 %
#   validation loss:	0.240268
#   validation accuracy:	91.10 %
# Epoch 26 of 40 took 1.815s
#   training loss:	0.331184
#   Training accuracy:	81.22 %
#   validation loss:	0.218947
#   validation accuracy:	90.87 %
# Epoch 27 of 40 took 2.212s
#   training loss:	0.336016
#   Training accuracy:	80.51 %
#   validation loss:	0.230934
#   validation accuracy:	92.30 %
# Epoch 28 of 40 took 1.889s
#   training loss:	0.322552
#   Training accuracy:	81.22 %
#   validation loss:	0.215552
#   validation accuracy:	91.56 %
# Epoch 29 of 40 took 2.050s
#   training loss:	0.323044
#   Training accuracy:	82.23 %
#   validation loss:	0.210381
#   validation accuracy:	91.42 %
# Epoch 30 of 40 took 2.162s
#   training loss:	0.313474
#   Training accuracy:	81.51 %
#   validation loss:	0.213853
#   validation accuracy:	92.62 %
# Epoch 31 of 40 took 2.248s
#   training loss:	0.324957
#   Training accuracy:	81.30 %
#   validation loss:	0.207112
#   validation accuracy:	92.72 %
# Epoch 32 of 40 took 2.049s
#   training loss:	0.320435
#   Training accuracy:	81.64 %
#   validation loss:	0.217867
#   validation accuracy:	90.78 %
# Epoch 33 of 40 took 1.811s
#   training loss:	0.315810
#   Training accuracy:	81.56 %
#   validation loss:	0.224431
#   validation accuracy:	92.58 %
# Epoch 34 of 40 took 1.945s
#   training loss:	0.321973
#   Training accuracy:	81.68 %
#   validation loss:	0.212243
#   validation accuracy:	92.21 %
# Epoch 35 of 40 took 1.851s
#   training loss:	0.307891
#   Training accuracy:	82.06 %
#   validation loss:	0.205323
#   validation accuracy:	92.62 %
# Epoch 36 of 40 took 1.680s
#   training loss:	0.309205
#   Training accuracy:	81.30 %
#   validation loss:	0.205732
#   validation accuracy:	93.22 %
# Epoch 37 of 40 took 1.982s
#   training loss:	0.313986
#   Training accuracy:	81.72 %
#   validation loss:	0.194401
#   validation accuracy:	93.18 %
# Epoch 38 of 40 took 1.952s
#   training loss:	0.301024
#   Training accuracy:	83.02 %
#   validation loss:	0.191775
#   validation accuracy:	92.49 %
# Epoch 39 of 40 took 1.959s
#   training loss:	0.326355
#   Training accuracy:	82.18 %
#   validation loss:	0.199888
#   validation accuracy:	92.95 %
# Epoch 40 of 40 took 2.035s
#   training loss:	0.290663
#   Training accuracy:	82.43 %
#   validation loss:	0.189090
#   validation accuracy:	93.18 %
# Final results:
#   testing loss:	0.163840
#   testing accuracy:	92.47 %

# %% [markdown]
# ## Sliding window

# %%
eval_fn = theano.function([input_var], val_prediction)
output = np.zeros((test_img.shape[0], test_img.shape[1], 2))


# Run the classifier on each patch in the validation image.

margin = int(math.floor(box_size / 2))
for x in xrange(margin, int(test_img.shape[0] - margin)):
    for y in xrange(margin, int(test_img.shape[1]-margin)):
        patch = test_img[x-margin:x+margin+1, y-margin:y+margin+1]
        patch = patch.reshape(1,1, box_size, box_size)
        output[x,y,:] = eval_fn(patch)

# %% [markdown]
# ## Detect local maxima

# %%
# Smooth the response map
heatmap = filters.gaussian_filter(output[:,:,1], 1) 
# Thresholding
seg = heatmap>0.5
# Non-maximum suppression
detections = np.where(np.multiply(seg, heatmap == filters.maximum_filter(heatmap, 3)))

# %% [markdown]
# ## Plot detections

# %%
fig, ax = plt.subplots()
ax.imshow(test_img, interpolation='nearest', cmap=plt.cm.gray)
plt.plot(detections[1], detections[0], 'b.', markersize=12, mew=3)
        
ax.axis('image')
ax.set_xticks([])
ax.set_yticks([])
plt.show()
plt.rcParams['figure.figsize'] = 20,20
